# %%
from matplotlib.pyplot import imshow
import numpy as np
import cv2
from keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential


np.random.seed(42)

SIZE=256
img_data=[]

img=cv2.imread('images/monalisa.jpg', 1)   #Change 1 to 0 for grey images
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Changing BGR to RGB to show images in true colors
img=cv2.resize(img,(SIZE, SIZE))
img_data.append(img_to_array(img))

img_array = np.reshape(img_data, (len(img_data), SIZE, SIZE, 3))
img_array = img_array.astype('float32') / 255.


model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
 

model.add(MaxPooling2D((2, 2), padding='same'))
     
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.summary()



model.fit(img_array, img_array,
        epochs=5000,
        shuffle=True)


print("Neural network output")
pred = model.predict(img_array)



imshow(pred[0].reshape(SIZE,SIZE,3), cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 import numpy as np
#       3 import cv2
# ----> 4 from keras.preprocessing.image import img_to_array
#       5 from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
#       6 from tensorflow.keras.models import Sequential
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\models\__init__.py:18, in <module>
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:34, in <module>
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.legacy import serialization
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py:32, in <module>
#      30 from keras.engine import base_layer
#      31 from keras.engine import base_layer_utils
# ---> 32 from keras.engine import compile_utils
#      33 from keras.engine import data_adapter
#      34 from keras.engine import input_layer as input_layer_module
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\compile_utils.py:24, in <module>
#      21 import tensorflow.compat.v2 as tf
#      23 from keras import losses as losses_mod
# ---> 24 from keras import metrics as metrics_mod
#      25 from keras.saving import saving_lib
#      26 from keras.utils import generic_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\metrics\__init__.py:84, in <module>
#      81 from keras.metrics.regression_metrics import mean_squared_logarithmic_error
#      83 # Confusion metrics
# ---> 84 from keras.metrics.confusion_metrics import AUC
#      85 from keras.metrics.confusion_metrics import FalseNegatives
#      86 from keras.metrics.confusion_metrics import FalsePositives
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\metrics\confusion_metrics.py:22, in <module>
#      19 import numpy as np
#      20 import tensorflow.compat.v2 as tf
# ---> 22 from keras import activations
#      23 from keras import backend
#      24 from keras.dtensor import utils as dtensor_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\activations.py:21, in <module>
#      17 import sys
#      19 import tensorflow.compat.v2 as tf
# ---> 21 import keras.layers.activation as activation_layers
#      22 from keras import backend
#      23 from keras.saving.legacy import serialization as legacy_serialization
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\layers\__init__.py:20, in <module>
#      17 import tensorflow.compat.v2 as tf
#      19 from keras.engine.base_layer import Layer
# ---> 20 from keras.engine.base_preprocessing_layer import PreprocessingLayer
#      22 # Generic layers.
#      23 from keras.engine.input_layer import Input
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\base_preprocessing_layer.py:21, in <module>
#      17 import abc
#      19 import tensorflow.compat.v2 as tf
# ---> 21 from keras.engine import data_adapter
#      22 from keras.engine.base_layer import Layer
#      23 from keras.utils import version_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\data_adapter.py:44, in <module>
#      41 from tensorflow.python.util.tf_export import keras_export
#      43 try:
# ---> 44     import pandas as pd
#      45 except ImportError:
#      46     pd = None
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py:22, in <module>
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\__init__.py:15, in <module>
#      12 import sys
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_version_under1p19,
#      18     np_version_under1p20,
#      19 )
#      20 from pandas.compat.pyarrow import (
#      21     pa_version_under1p01,
#      22     pa_version_under2p0,
#      23     pa_version_under3p0,
#      24     pa_version_under4p0,
#      25 )
#      27 PY39 = sys.version_info >= (3, 9)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py:4, in <module>
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\__init__.py:1, in <module>
# ----> 1 from pandas.util._decorators import (  # noqa:F401
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa:F401
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:14, in <module>
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa:F401
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\__init__.py:13, in <module>
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\missing.pyx:1, in init pandas._libs.missing()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\__init__.py:30, in <module>
#       1 __all__ = [
#       2     "dtypes",
#       3     "localize_pydatetime",
#    (...)
#      26     "tz_compare",
#      27 ]
#      29 from pandas._libs.tslibs import dtypes
# ---> 30 from pandas._libs.tslibs.conversion import (
#      31     OutOfBoundsTimedelta,
#      32     localize_pydatetime,
#      33 )
#      34 from pandas._libs.tslibs.dtypes import Resolution
#      35 from pandas._libs.tslibs.nattype import (
#      36     NaT,
#      37     NaTType,
#      38     iNaT,
#      39     nat_strings,
#      40 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:63, in init pandas._libs.tslibs.conversion()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:1, in init pandas._libs.tslibs.parsing()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:1, in init pandas._libs.tslibs.offsets()
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:
